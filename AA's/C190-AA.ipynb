# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Launch_Date.csv')
df
# Out:
#      Unnamed: 0      #                                               Name  \
# 0           115  116.0  PS4 Stage attached with ExseedSat-2, AMSAT, AR...
# 1           114  115.0                                             EMISAT
# 2            68   69.0                                           IRNSS-1A
# 3             9   10.0                                           INSAT-1B
# 4           106  107.0                                            GSAT-29
# ..          ...    ...                                                ...
# 117          75   76.0                                            GSAT-16
# 118          91   92.0                                     ResourceSat-2A
# 119           1    2.0                                    Bhaskara Sega-I
# 120          36   37.0                                 GSAT-2 (GramSat-2)
# 121          86   87.0                                          INSAT-3DR
#
#                                             Discipline  COSPAR ID SatCat #  \
# 0    Amateur radio applications, Ionospheric studie...        NaN      NaN
# 1    Reconnaissance of electromagnetic spectrum (EL...  2019-018A    44078
# 2                        Navigation/Global Positioning  2013-034A    39199
# 3                        Communications Earth Sciences  1983-089B    14318
# 4              High-throughput Communication Satellite  2018-089A    43698
# ..                                                 ...        ...      ...
# 117                                     Communications  2014-078A    40332
# 118                                     Earth Sciences  2016-074A    41877
# 119  Astronomy Communications Engineering Earth Sci...  1979-051A    11392
# 120                                     Communications  2003-018A    27807
# 121                                     Earth Sciences  2016-054A    41752
#
#                Launch Mass           Dry Mass On-board Power  \
# 0                      NaN                NaN            NaN
# 1          436 kg (961 lb)                NaN          800 W
# 2      1,425 kg (3,142 lb)  614 kg (1,354 lb)         1660 W
# 3      1,152 kg (2,540 lb)                NaN            NaN
# 4      3,423 kg (7,546 lb)                NaN            NaN
# ..                     ...                ...            ...
# 117  3,181.6 kg (7,014 lb)                NaN         6000 W
# 118    1,235 kg (2,723 lb)                NaN            NaN
# 119        444 kg (979 lb)                NaN           47 W
# 120    1,900 kg (4,200 lb)                NaN         1400 W
# 121    2,211 kg (4,874 lb)  956 kg (2,108 lb)         1700 W
#
#                         Launch Date  ...                  Periapsis  \
# 0           1 April 2019, 09:27 IST  ...                        NaN
# 1           1 April 2019, 09:27 IST  ...        739.3 km (459.4 mi)
# 2         1 July 2013, 23:41:00 IST  ...  35,720.2 km (22,195.5 mi)
# 3         1 June 1983, 13:19:00 IST  ...  35,776.2 km (22,230.3 mi)
# 4            1 November 2018, 11:38  ...                        NaN
# ..                              ...  ...                        ...
# 117    7 December 2014, 2:10:00 IST  ...  35,762.5 km (22,221.8 mi)
# 118   7 December 2016, 10:24:00 IST  ...        826.3 km (513.4 mi)
# 119       7 June 1979, 16:00:00 IST  ...            512 km (318 mi)
# 120        8 May 2003, 16:58:00 IST  ...  35,892.6 km (22,302.6 mi)
# 121  8 September 2016, 16:40:00 IST  ...  35,767.2 km (22,224.7 mi)
#
#                       Apoapsis        Semi-Major Axis        Period  \
# 0              485 km (301 mi)                    NaN           NaN
# 1          767.6 km (477.0 mi)    7,124 km (4,427 mi)  99.7 minutes
# 2    35,864.3 km (22,285.0 mi)  42,163 km (26,199 mi)   1436.0 mins
# 3    35,869.6 km (22,288.3 mi)  42,193 km (26,218 mi)   1437.6 mins
# 4                          NaN                    NaN      13 hours
# ..                         ...                    ...           ...
# 117  35,824.7 km (22,260.4 mi)  42,164 km (26,199 mi)   1436.1 mins
# 118        827.6 km (514.2 mi)    7,197 km (4,472 mi)    101.3 mins
# 119            557 km (346 mi)                    NaN     95.2 mins
# 120  35,936.5 km (22,329.9 mi)  42,285 km (26,275 mi)   1442.3 mins
# 121  35,820.6 km (22,257.9 mi)  42,164 km (26,199 mi)   1436.1 mins
#
#         Inclination Longitude Eccentricity                Epoch Start  \
# 0               NaN       NaN          NaN                        NaN
# 1    98.376 degrees       NaN          NaN                        NaN
# 2             28.8°   55.0° E          NaN                        NaN
# 3             14.8°  89.71° E          NaN  31 May 1983, 09:19:00 IST
# 4       8.9 degrees       NaN          NaN                        NaN
# ..              ...       ...          ...                        ...
# 117            0.1°   55.0° E          NaN                        NaN
# 118           98.7°       NaN          NaN                        NaN
# 119           50.7°       NaN      0.00325  7 June 1979, 01:30:00 IST
# 120              5°    199° W          NaN                        NaN
# 121            0.0°   74.0° E          NaN                        NaN
#
#            Decay Date                                               Note
# 0                 NaN  Utilization of fourth stage directly as a sate...
# 1                 NaN  Electromagnetic intelligence to track any enem...
# 2                 NaN  IRNSS-1A is the first of seven satellite in th...
# 3                 NaN  Identical to INSAT-1A. Served for more than de...
# 4                 NaN                                                NaN
# ..                ...                                                ...
# 117               NaN  GSAT-16 is the twenty fourth communication sat...
# 118               NaN  Its mission is identical to its predecessors (...
# 119  17 February 1989  First experimental remote sensing satellite. C...
# 120               NaN  Experimental satellite for the second developm...
# 121               NaN  An advanced meteorological satellite of India ...
#
# [122 rows x 22 columns]

# %%
#Additional-Activity-1
#The "raw.csv" file is sorted in descending order
#So read the CSV and get the name and date of the Satellites which was launched recently

#predefine code
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Launch_Date.csv')
df
#predefine code end

recent_satellites = df.head(1)

print("Recently On : ")
print (recent_satellites['Launch Date'])
print(recent_satellites['Name'])
print("Satellites had launched")
# Out:
# Recently On :
# 115    1 April 2019, 09:27 IST
# Name: Launch Date, dtype: object
# 115    PS4 Stage attached with ExseedSat-2, AMSAT, AR...
# Name: Name, dtype: object
# Satellites had launched

# %%
#Additional-Activity-2
#The "raw.csv" file is sorted in descending order
#So read the CSV and get the name and date of the Satellites which was launched earliest

earliest_satellites = df.tail(1)

print("Oldest On : ")
print (earliest_satellites['Launch Date'])
print(earliest_satellites['Name'])
print("Satellites had launched")
# Out:
# Oldest On :
# 86    8 September 2016, 16:40:00 IST
# Name: Launch Date, dtype: object
# 86    INSAT-3DR
# Name: Name, dtype: object
# Satellites had launched

# %%
#Additional-Activity-3
#The "Launch Mass.csv" file is sorted in ascending order
#Read the csv such that you get the 5 least heavy Launch Vehicle name and they weight and convert it into list and print them

#predefine code
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Launch Mass.csv')
df
#predefine code end

least_heavy_5 = df.head(5)
mass = least_heavy_5['Launch Mass'].tolist()
launch_vehicle = least_heavy_5['Launch Vehicle'].tolist()
print(mass)
print(launch_vehicle)
# Out:
# ['< 1\xa0kg (2.2\xa0lb)', '975\xa0kg (2,150\xa0lb)', '975\xa0kg (2,150\xa0lb)', '960\xa0kg (2,120\xa0lb)', '930\xa0kg (2,050\xa0lb)']
# ['PSLV-C15', 'Vostok', 'Vostok', 'PSLV-C14', 'PSLV-D3']

# %%
#Additional-Activity-4
#The "Launch Mass.csv" file is sorted in ascending order
#Plot the 5 least heavy Launch Vehicle name and they weight

#predefine code
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Launch Mass.csv')
df

least_heavy_5 = df.head(5)
mass = least_heavy_5['Launch Mass']
launch_vehicle = least_heavy_5['Launch Vehicle']
print(mass)
print(launch_vehicle)
#predefine code end

plt.xlabel("Launch Vehicle")
plt.xticks(rotation='vertical')
plt.ylabel("Launch Mass")


label = launch_vehicle
value = mass 
plt.bar(label, value,width=0.4, color=('red','blue','green','pink','yellow')) #bar-grap
# Out:
# 0      < 1 kg (2.2 lb)
# 1    975 kg (2,150 lb)
# 2    975 kg (2,150 lb)
# 3    960 kg (2,120 lb)
# 4    930 kg (2,050 lb)
# Name: Launch Mass, dtype: object
# 0    PSLV-C15
# 1      Vostok
# 2      Vostok
# 3    PSLV-C14
# 4     PSLV-D3
# Name: Launch Vehicle, dtype: object
# <BarContainer object of 5 artists>

# %%
#Additional-Activity-5
#The "Launch Mass.csv" file is sorted in ascending order
#Plot the 5 heaviest Launch Vehicle name and they weight

#predefine code
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('Launch Mass.csv')
df
#predefine code end

heaviest_5 = df.tail(5)
mass = heaviest_5['Launch Mass']
launch_vehicle = heaviest_5['Launch Vehicle']
print(mass)
print(launch_vehicle)

plt.xlabel("Launch Vehicle")
plt.xticks(rotation='vertical')
plt.ylabel("Launch Mass")


label = launch_vehicle
value = mass 
plt.bar(label, value,width=0.4, color=('red','blue','green','pink','yellow')) #bar-grap
# Out:
# 116    1,152.1 kg (2,540 lb)
# 117      1,108 kg (2,443 lb)
# 118      1,060 kg (2,340 lb)
# 119      1,050 kg (2,310 lb)
# 120      1,000 kg (2,200 lb)
# Name: Launch Mass, dtype: object
# 116    Delta 3910 PAM-D
# 117             PSLV-C3
# 118             PSLV-C4
# 119             PSLV-C2
# 120            PSLV-C18
# Name: Launch Vehicle, dtype: object
# <BarContainer object of 5 artists>
